# %%
import data_management as dm

FINAL_DICT = dm.load_final_dict()
# Out:
# [FULL_DICT]
# · 220개
# · 업데이트 날짜: 2025-12-11 14:08:35.915610
# [err_image_paths]
# · 5개
# · 업데이트 날짜: 2025-12-12 10:34:10.059084
# [FIXED_DICT]
# · 13개
# · 업데이트 날짜: 2025-12-11 15:26:02.915623
#
# <<FINAL_DICT 불러오기 완료>>
# · 총 228개
# · 지니 계수(불평등도): 0.494

# %%
print(dm.calculate_gini(FINAL_DICT))
# Out:
# 0.494
