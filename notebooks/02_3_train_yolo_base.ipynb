# %%
"""
수정 예정입니다
학습 기본 토대입니다
사용 금지
사용 금지
사용 금지
사용 금지
사용 금지
사용 금지
"""

import data_management as dm

# FINAL_DICT 불러오기
FINAL_DICT = dm.load_final_dict()

# yaml 파일 생성
dm.make_data_yaml()

# 학습코드 설계
model = "asdfasdfasdf"

# 학습
model.train()

# 제출용 csv 파일 생성
dm.yolo_to_csv()
