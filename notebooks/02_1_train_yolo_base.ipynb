# %%
"""
수정 예정입니다
학습 기본 토대입니다
사용 금지
사용 금지
사용 금지
사용 금지
사용 금지
사용 금지
"""

import data_management as dm

# FINAL_DICT 불러오기
FINAL_DICT = dm.load_final_dict()

# yaml 파일 생성
dm.make_data_yaml()

# 학습코드 설계
model = "asdfasdfasdf"

# 학습
model.train()

# 제출용 csv 파일 생성
dm.yolo_to_csv()
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11ZSWLtsCERqCnn3LW8hLkNoabzXMTuF9
# To: /Users/won/dev/codeit/0_mission/100_DL_ObjectDetection/data/err_image_paths.txt
# 100%|██████████| 236/236 [00:00<00:00, 273kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=12lXHbkQNowGtk5AxtJZ3638qVLhSwxHh
# To: /Users/won/dev/codeit/0_mission/100_DL_ObjectDetection/data/FIXED_DICT.json
# 100%|██████████| 9.07k/9.07k [00:00<00:00, 847kB/s]
# [업데이트 완료]
# · err_image_paths 업데이트 날짜: 2025-12-12 14:32:42
# · FIXED_DICT 업데이트 날짜: 2025-12-12 14:32:42
