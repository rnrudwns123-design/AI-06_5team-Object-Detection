# %%
"""
수정 예정입니다 
사용 금지
사용 금지
사용 금지
사용 금지
사용 금지
사용 금지
"""

# import data_management as dm

# FINAL_DICT = dm.load_final_dict()

# dm.make_data_yaml()
# Out:
# [FULL_DICT]
# · 220개
# · 업데이트 날짜: 2025-12-11 14:08:35.915610
# [err_image_paths]
# · 5개
# · 업데이트 날짜: 2025-12-10 13:22:13.755317
# [FIXED_DICT]
# · 13개
# · 업데이트 날짜: 2025-12-11 15:26:02.915623
#
# <<FINAL_DICT 불러오기 완료>> (총 228개)
