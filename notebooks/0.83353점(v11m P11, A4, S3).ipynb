# %%
# !pip install -q ultralytics gdown wandb pyyaml opencv-python-headless
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.5 MB/s eta 0:00:00

# %%
# !mkdir -p /content/gdrive   ( 빈 폴더(gdrive) 생성)

# %%
from google.colab import drive
drive.mount('/content/gdrive') # 그냥 drive면 수정
# (선택) 꼬였을 때 강제 재마운트
# drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# =========================
# Run Context & Path Setup
# =========================
from pathlib import Path
from datetime import datetime
import shutil

# 1) 날짜
date_tag = datetime.now().strftime("%Y%m%d")

# 2) 실험 이름 (🔥 여기만 바꾸면 됨)
run_name = f"{date_tag}_y11m_640_b16_e40_afterpad11_A4_S2?"

# 3) 프로젝트 루트
ROOT_DIR = Path("/content/gdrive/MyDrive/AI-06_5team-Object-Detection")

# 4) 데이터 경로
DATA_DIR = ROOT_DIR / "data"
YOLO_BASE_PATH = Path("/content/yolo_dataset") # ✅ 로컬로 변경 (초고속)

TRAIN_IMAGE_DIR = DATA_DIR / "train_images"
TEST_DIR  = DATA_DIR / "test_images"

# 5) YOLO runs 경로
RUNS_DIR = ROOT_DIR / "notebooks" / "yolo_runs"
RUN_DIR = RUNS_DIR / run_name
RUN_DIR.mkdir(parents=True, exist_ok=True)

# 6) run 전용 data.yaml 위치
DATA_YAML_PATH = RUN_DIR / "data.yaml"

print("ROOT_DIR:", ROOT_DIR)
print("DATA_DIR:", DATA_DIR)
print("샘플 이미지 수:", len(list(TRAIN_IMAGE_DIR.iterdir())))
# Out:
# ROOT_DIR: /content/gdrive/MyDrive/AI-06_5team-Object-Detection
# DATA_DIR: /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data
# 샘플 이미지 수: 651

# %%
# =========================
# 데이터셋 생성 시작 직전
# =========================

# (선택) YOLO_BASE_PATH를 통째로 새로 만들고 싶을 때만
# ⚠️ 이 줄 아래부터 데이터 다시 만들어짐
# shutil.rmtree(YOLO_BASE_PATH, ignore_errors=True)
# YOLO_BASE_PATH.mkdir(parents=True, exist_ok=True)

# ↓↓↓ 여기부터 FINAL_DICT / make_split / data.yaml 생성 ↓↓↓

# %%
import json, shutil
from pathlib import Path
from PIL import Image
from sklearn.model_selection import train_test_split
import yaml
from collections import Counter
import random

# --- 경로 ---
FIXED_DICT_PATH = DATA_DIR / "FIXED_DICT.json"
ERR_TXT_PATH = DATA_DIR / "err_image_paths.txt"

# 1) load fixed dict
with open(FIXED_DICT_PATH, "r", encoding="utf-8") as f:
    FIXED_DICT = json.load(f)

# 2) error images (옵션)
err_images = set()
if ERR_TXT_PATH.exists():
    with open(ERR_TXT_PATH, "r", encoding="utf-8") as f:
        err_images = {line.strip() for line in f if line.strip()}

# 3) FINAL_DICT
FINAL_DICT = {}
missing = 0

for img_name, ann_list in FIXED_DICT.items():
    img_path = TRAIN_IMAGE_DIR / img_name
    if not img_path.exists():
        missing += 1
        continue

    FINAL_DICT[str(img_path)] = [
        {"bbox": ann["bbox"], "label": str(ann["label"])}
        for ann in ann_list
        if isinstance(ann, dict) and "bbox" in ann and "label" in ann
    ]

print(f"✅ FINAL_DICT: {len(FINAL_DICT)}개 (missing skipped: {missing})")
if not FINAL_DICT:
    raise ValueError("FINAL_DICT가 비었습니다.")
# Out:
# ✅ FINAL_DICT: 651개 (missing skipped: 0)

# %%
# =========================
# class mapping
# =========================
labels = sorted(
    {a["label"] for anns in FINAL_DICT.values() for a in anns},
    key=lambda x: int(x)
)

label_to_idx = {l: i for i, l in enumerate(labels)}
idx_to_label = {i: l for l, i in label_to_idx.items()}
idx_to_category_id = {i: int(idx_to_label[i]) for i in idx_to_label}

print("✅ 클래스 수(nc):", len(label_to_idx))

# =========================
# 1) 라벨 빈도 계산
# =========================
all_labels = []
for anns in FINAL_DICT.values():
    for a in anns:
        all_labels.append(a["label"])
label_counts = Counter(all_labels)

# =========================
# 2) 이미지별 대표(희귀) 라벨로 stratify
# =========================
image_paths = list(FINAL_DICT.keys())
stratify_labels = []

for p in image_paths:
    anns = FINAL_DICT[p]
    rare = min(label_counts[a["label"]] for a in anns)
    rare_label = min(
        anns, key=lambda a: label_counts[a["label"]]
    )["label"]
    stratify_labels.append(label_to_idx[rare_label])

train_imgs, val_imgs = train_test_split(
    image_paths,
    test_size=0.2,
    random_state=42,
    stratify=stratify_labels
)

print("✅ split 완료:", len(train_imgs), len(val_imgs))

# =========================
# 3) 🔥 오버샘플링 (불균형 핵심)
# =========================
def image_rarity_score(img_path):
    anns = FINAL_DICT[img_path]
    return min(label_counts[a["label"]] for a in anns)

oversampled_train = []
for p in train_imgs:
    r = image_rarity_score(p)
    if r <= 2:
        k = 8
    elif r <= 5:
        k = 5
    elif r <= 10:
        k = 3
    else:
        k = 1
    oversampled_train.extend([p] * k)

random.shuffle(oversampled_train)

print("🔥 train 원본:", len(train_imgs))
print("🔥 train 오버샘플:", len(oversampled_train))
# Out:
# ✅ 클래스 수(nc): 74
# ✅ split 완료: 520 131
# 🔥 train 원본: 520
# 🔥 train 오버샘플: 612

# %%
# =========================
# YOLO folder structure
# =========================
for p in [
    YOLO_BASE_PATH / "images/train",
    YOLO_BASE_PATH / "images/val",
    YOLO_BASE_PATH / "labels/train",
    YOLO_BASE_PATH / "labels/val",
]:
    p.mkdir(parents=True, exist_ok=True)

def xywh_to_yolo(bbox, w, h):
    x, y, bw, bh = bbox
    return [(x + bw/2)/w, (y + bh/2)/h, bw/w, bh/h]

def make_split(imgs, split):
    img_out = YOLO_BASE_PATH / f"images/{split}"
    lbl_out = YOLO_BASE_PATH / f"labels/{split}"

    for img_path in imgs:
        p = Path(img_path)
        with Image.open(p) as im:
            w, h = im.size

        shutil.copy(str(p), str(img_out / p.name))

        with open(lbl_out / f"{p.stem}.txt", "w") as f:
            for ann in FINAL_DICT[str(p)]:
                cid = label_to_idx[ann["label"]]
                bb = xywh_to_yolo(ann["bbox"], w, h)
                f.write(f"{cid} {' '.join(f'{v:.6f}' for v in bb)}\n")

make_split(oversampled_train, "train")
make_split(val_imgs, "val")

# =========================
# data.yaml
# =========================
data_yaml = {
    "path": str(YOLO_BASE_PATH.resolve()),
    "train": "images/train",
    "val": "images/val",
    "nc": len(label_to_idx),
    "names": {i: idx_to_category_id[i] for i in range(len(idx_to_category_id))},
}

with open(DATA_YAML_PATH, "w", encoding="utf-8") as f:
    yaml.safe_dump(data_yaml, f, allow_unicode=True, sort_keys=False)

print("🎉 YOLO dataset ready")
print("📄 data.yaml:", DATA_YAML_PATH)
# Out:
# 🎉 YOLO dataset ready
# 📄 data.yaml: /content/gdrive/MyDrive/AI-06_5team-Object-Detection/notebooks/yolo_runs/20251217_y11m_640_b16_e40_afterpad11_A4_S2?/data.yaml

# %%
# (A) sanity check
import random
import matplotlib.pyplot as plt
import matplotlib.patches as patches

sample_imgs = random.sample(list(FINAL_DICT.keys()), k=3)

for img_path in sample_imgs:
    p = Path(img_path)
    im = Image.open(p).convert("RGB")

    fig, ax = plt.subplots(figsize=(6, 6))
    ax.imshow(im)

    for ann in FINAL_DICT[str(p)]:
        x, y, bw, bh = ann["bbox"]
        rect = patches.Rectangle((x, y), bw, bh, fill=False, linewidth=2)
        ax.add_patch(rect)
        ax.text(x, y, ann["label"], fontsize=9)

    ax.set_title(p.name)
    ax.axis("off")
    plt.show()

# %%
from ultralytics import YOLO
import pandas as pd

# =========================
#  YOLO 모델 로드
# =========================
model = YOLO("yolo11m.pt")

# =========================
#  학습
# =========================
results = model.train(
    data=str(DATA_YAML_PATH),   # run 전용 data.yaml
    epochs=40,
    imgsz=640,
    batch=16,
    seed=42,
    patience=20,
    device=0,
    workers=4,

    # 👇 여기부터 A4 증강 세팅
    # 기하학 변형
    degrees=5.0,        # ±5도 회전 (촬영 각도 개인차)
    translate=0.02,     # 2% 정도 평행 이동 (5% -> 2%) ✅
    scale=0.05,         # 5% 확대/축소 (10% -> 5%) ✅
    shear=0.0,          # 각인 찌그러짐 방지
    perspective=0.0,    # 원근 왜곡 X
    fliplr=0.0,         # 좌우반전 X (각인 방향 보존)
    flipud=0.0,         # 상하반전 X

    # 색/밝기 (ColorJitter + BrightnessContrast 느낌)
    hsv_h=0.02,         # 색조 살짝 변화
    hsv_s=0.30,         # 채도 적당히
    hsv_v=0.20,         # 밝기 적당히


    # 모자이크/믹스업 등
    # mosaic=0.05,        # 이거 없애봄 ✅
    mixup=0.0,
    erasing=0.0,
    auto_augment=None,
    # 여기까지 증강 끝

    save=True,
    plots=True,

    project=str(RUNS_DIR),      # 결과 저장 루트
    name=run_name,              # 결과 폴더 = run_name
    exist_ok=True,              # 폴더 1개만 생성 유지
)

RUN_DIR = Path(results.save_dir)   # 진짜 저장 폴더로 확정
print("✅ REAL RUN_DIR:", RUN_DIR)
print("✅ 학습 완료!")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11m.pt to 'yolo11m.pt': 100% ━━━━━━━━━━━━ 38.8MB 190.9MB/s 0.2s
# Ultralytics 8.3.239 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=None, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/gdrive/MyDrive/AI-06_5team-Object-Detection/notebooks/yolo_runs/20251217_y11m_640_b16_e40_afterpad11_A4_S2?/data.yaml, degrees=5.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=40, erasing=0.0, exist_ok=True, fliplr=0.0, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.02, hsv_s=0.3, hsv_v=0.2, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=20251217_y11m_640_b16_e40_afterpad11_A4_S2?, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/gdrive/MyDrive/AI-06_5team-Object-Detection/notebooks/yolo_runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/gdrive/.shortcut-targets-by-id/1po9nINU9wzcKmM6FW0IqwLgoEDz32UTZ/AI-06_5team-Object-Detection/notebooks/yolo_runs/20251217_y11m_640_b16_e40_afterpad11_A4_S2?, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.05, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.02, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 13.6MB/s 0.1s
# Overriding model.yaml nc=80 with nc=74
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1468078  ultralytics.nn.modules.head.Detect           [74, [256, 512, 512]]
# YOLO11m summary: 231 layers, 20,110,062 parameters, 20,110,046 gradients, 68.5 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 61.6MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5058.1±1249.9 MB/s, size: 1705.9 KB)
# train: Scanning /content/yolo_dataset/labels/train... 520 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 520/520 494.4it/s 1.1s
# train: New cache created: /content/yolo_dataset/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3189.8±2208.6 MB/s, size: 1703.6 KB)
# val: Scanning /content/yolo_dataset/labels/val... 131 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 131/131 428.8it/s 0.3s
# val: New cache created: /content/yolo_dataset/labels/val.cache
# Plotting labels to /content/gdrive/.shortcut-targets-by-id/1po9nINU9wzcKmM6FW0IqwLgoEDz32UTZ/AI-06_5team-Object-Detection/notebooks/yolo_runs/20251217_y11m_640_b16_e40_afterpad11_A4_S2?/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000128, momentum=0.9) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.0005), 112 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /content/gdrive/.shortcut-targets-by-id/1po9nINU9wzcKmM6FW0IqwLgoEDz32UTZ/AI-06_5team-Object-Detection/notebooks/yolo_runs/20251217_y11m_640_b16_e40_afterpad11_A4_S2?
# Starting training for 40 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/40      7.98G     0.5676      3.689     0.9929         53        640: 100% ━━━━━━━━━━━━ 33/33 1.0s/it 33.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.3s/it 6.4s
#                    all        131        492      0.362      0.325      0.276      0.249
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/40      8.21G     0.4555      1.586     0.9027         45        640: 100% ━━━━━━━━━━━━ 33/33 1.9it/s 17.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s
#                    all        131        492      0.709      0.701      0.723      0.662
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/40       8.2G     0.4059     0.9746     0.8724         42        640: 100% ━━━━━━━━━━━━ 33/33 1.9it/s 17.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.777      0.813      0.873      0.796
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/40      8.25G     0.3948     0.7311     0.8666         53        640: 100% ━━━━━━━━━━━━ 33/33 1.9it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s
#                    all        131        492      0.831      0.887      0.931       0.89
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/40      8.18G     0.3639     0.5857     0.8606         54        640: 100% ━━━━━━━━━━━━ 33/33 1.9it/s 17.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s
#                    all        131        492      0.919      0.913      0.978      0.958
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/40      8.25G     0.3281      0.502     0.8479         53        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.885      0.935      0.995      0.936
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/40      8.25G     0.3356     0.4642     0.8489         44        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.937      0.953      0.995      0.948
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/40      8.23G     0.3422     0.4362     0.8496         48        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s
#                    all        131        492      0.913      0.974      0.995       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/40      8.18G     0.3227     0.4151     0.8452         47        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.961      0.962      0.995      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/40      8.25G      0.317     0.3906     0.8444         49        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.974      0.947      0.995      0.984
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/40      8.26G     0.3143     0.3716     0.8417         45        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s
#                    all        131        492      0.958      0.961      0.995       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/40      8.25G     0.3377      0.357     0.8498         44        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.946       0.98      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/40      8.19G     0.2833     0.3149     0.8295         50        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.973       0.98      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/40      8.26G     0.2879     0.3211     0.8321         46        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.967      0.954      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/40      8.25G       0.28     0.3064     0.8372         52        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s
#                    all        131        492      0.974      0.972      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/40      8.26G     0.2762     0.2915     0.8349         55        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s
#                    all        131        492      0.968      0.975      0.995      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/40      8.18G     0.2854     0.3016     0.8349         48        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.966      0.964      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/40      8.25G     0.2702     0.2778     0.8307         48        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.979      0.983      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/40      8.24G     0.2772     0.2838     0.8372         48        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s
#                    all        131        492      0.971      0.979      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/40      8.26G     0.2712     0.2831     0.8337         49        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.952      0.977      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/40      8.16G     0.2566     0.2627     0.8321         47        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.978      0.982      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/40      8.25G     0.2621      0.253     0.8282         48        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.974      0.982      0.995       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/40      8.25G     0.2607     0.2545     0.8322         54        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.975      0.981      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/40      8.24G     0.2462     0.2303     0.8254         48        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.975      0.982      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/40      8.17G     0.2484     0.2394     0.8297         44        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.972       0.98      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/40      8.26G     0.2452     0.2263     0.8296         47        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s
#                    all        131        492      0.971      0.978      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/40      8.25G     0.2295     0.2222     0.8205         48        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.954      0.982      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/40      8.25G     0.2263     0.2161     0.8253         56        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.981       0.97      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/40      8.18G     0.2293      0.221     0.8274         47        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.984      0.984      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/40      8.26G     0.2213     0.2143     0.8184         52        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s
#                    all        131        492      0.983      0.984      0.995      0.995
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/40      8.22G     0.1697     0.1619     0.7669         29        640: 100% ━━━━━━━━━━━━ 33/33 1.7it/s 18.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492       0.98      0.983      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/40      8.21G     0.1577     0.1515     0.7641         31        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.982      0.984      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/40      8.17G     0.1488     0.1491     0.7671         32        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.986      0.982      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/40      8.22G     0.1387     0.1407     0.7648         30        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.987      0.984      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/40      8.24G     0.1332     0.1361     0.7575         30        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.984      0.984      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/40      8.22G     0.1256     0.1317     0.7582         31        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.987      0.984      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/40      8.15G     0.1223     0.1293      0.763         31        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s
#                    all        131        492      0.987      0.984      0.995      0.995
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/40      8.23G     0.1195      0.126     0.7609         28        640: 100% ━━━━━━━━━━━━ 33/33 1.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s
#                    all        131        492      0.987      0.984      0.995      0.995
# EarlyStopping: Training stopped early as no improvement observed in last 20 epochs. Best results observed at epoch 18, best model saved as best.pt.
# To update EarlyStopping(patience=20) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 38 epochs completed in 0.225 hours.
# Optimizer stripped from /content/gdrive/.shortcut-targets-by-id/1po9nINU9wzcKmM6FW0IqwLgoEDz32UTZ/AI-06_5team-Object-Detection/notebooks/yolo_runs/20251217_y11m_640_b16_e40_afterpad11_A4_S2?/weights/last.pt, 40.6MB
# Optimizer stripped from /content/gdrive/.shortcut-targets-by-id/1po9nINU9wzcKmM6FW0IqwLgoEDz32UTZ/AI-06_5team-Object-Detection/notebooks/yolo_runs/20251217_y11m_640_b16_e40_afterpad11_A4_S2?/weights/best.pt, 40.6MB
#
# Validating /content/gdrive/.shortcut-targets-by-id/1po9nINU9wzcKmM6FW0IqwLgoEDz32UTZ/AI-06_5team-Object-Detection/notebooks/yolo_runs/20251217_y11m_640_b16_e40_afterpad11_A4_S2?/weights/best.pt...
# Ultralytics 8.3.239 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,087,086 parameters, 0 gradients, 68.0 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.5it/s 2.0s
#                    all        131        492      0.987      0.984      0.995      0.995
#                   1899         19         19      0.997          1      0.995      0.995
#                   2482         19         19      0.997          1      0.995      0.995
#                   3350         32         32      0.998          1      0.995      0.995
#                   3482         50         50      0.999          1      0.995      0.995
#                   3543         11         11      0.996          1      0.995      0.995
#                   3742          3          3      0.982          1      0.995      0.995
#                   3831          4          4       0.99          1      0.995      0.995
#                   4377          6          6       0.99          1      0.995      0.995
#                   4542          4          4      0.985          1      0.995      0.995
#                   5093          7          7      0.992          1      0.995      0.995
#                   5885          3          3      0.983          1      0.995      0.995
#                   6191          3          3      0.987          1      0.995      0.995
#                   6562          4          4      0.985          1      0.995      0.995
#                  10220          4          4      0.986          1      0.995      0.995
#                  12080          3          3      0.988          1      0.995      0.995
#                  12246          2          2      0.978          1      0.995      0.995
#                  12419          1          1      0.969          1      0.995      0.995
#                  12777          5          5      0.993          1      0.995      0.995
#                  13394          3          3      0.983          1      0.995      0.995
#                  13899          3          3      0.981          1      0.995      0.995
#                  16231          9          9      0.995          1      0.995      0.995
#                  16261         14         14      0.998          1      0.995      0.995
#                  16547         18         18      0.997          1      0.995      0.995
#                  16550         12         12      0.996          1      0.995      0.995
#                  16687          2          2      0.979          1      0.995      0.995
#                  18109          4          4      0.985          1      0.995      0.995
#                  18146          5          5          1      0.806      0.995      0.995
#                  18356          2          2      0.978          1      0.995      0.995
#                  19231          3          3      0.984          1      0.995      0.995
#                  19551          3          3      0.983          1      0.995      0.995
#                  19606          4          4      0.985          1      0.995      0.995
#                  19860          9          9      0.994          1      0.995      0.995
#                  20013          3          3      0.985          1      0.995      0.995
#                  20237         12         12      0.995          1      0.995      0.995
#                  20876          9          9      0.994          1      0.995      0.995
#                  21025          3          3      0.981          1      0.995      0.995
#                  21324          3          3      0.976          1      0.995      0.995
#                  21770          3          3      0.983          1      0.995      0.995
#                  22073          2          2      0.967          1      0.995      0.995
#                  22346         11         11      0.994          1      0.995      0.995
#                  22361          4          4      0.986          1      0.995      0.995
#                  22626          5          5       0.99          1      0.995      0.995
#                  23202          1          1          1          1      0.995      0.995
#                  23222          3          3      0.986          1      0.995      0.995
#                  24849          3          3      0.981          1      0.995      0.995
#                  25366          8          8      0.993          1      0.995      0.995
#                  25437          9          9      0.995          1      0.995      0.995
#                  25468          7          7      0.993          1      0.995      0.995
#                  27652          8          8      0.992          1      0.995      0.995
#                  27732          8          8      0.993          1      0.995      0.995
#                  27776          9          9      0.993          1      0.995      0.995
#                  27925          5          5      0.988          1      0.995      0.995
#                  27992          1          1      0.969          1      0.995      0.995
#                  28762          7          7      0.982          1      0.995      0.995
#                  29344          1          1      0.964          1      0.995      0.995
#                  29450          3          3      0.985          1      0.995      0.995
#                  29666         17         17      0.996          1      0.995      0.995
#                  29870          1          1      0.965          1      0.995      0.995
#                  30307          6          6       0.99          1      0.995      0.995
#                  31704          3          3      0.984          1      0.995      0.995
#                  31862          2          2      0.978          1      0.995      0.995
#                  31884         11         11      0.995          1      0.995      0.995
#                  32309          3          3      0.984          1      0.995      0.995
#                  33008          7          7          1          1      0.995      0.995
#                  33207          3          3      0.983          1      0.995      0.995
#                  33877          1          1          1          0      0.995      0.995
#                  33879          4          4      0.988          1      0.995      0.995
#                  34596          7          7      0.992          1      0.995      0.995
#                  35205         11         11      0.995          1      0.995      0.995
#                  36636          9          9      0.995          1      0.995      0.995
#                  38161          3          3      0.982          1      0.995      0.995
#                  41767          3          3      0.921          1      0.995      0.995
#                  44198          2          2      0.978          1      0.995      0.995
# Speed: 0.3ms preprocess, 9.9ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to /content/gdrive/.shortcut-targets-by-id/1po9nINU9wzcKmM6FW0IqwLgoEDz32UTZ/AI-06_5team-Object-Detection/notebooks/yolo_runs/20251217_y11m_640_b16_e40_afterpad11_A4_S2?
# ✅ REAL RUN_DIR: /content/gdrive/.shortcut-targets-by-id/1po9nINU9wzcKmM6FW0IqwLgoEDz32UTZ/AI-06_5team-Object-Detection/notebooks/yolo_runs/20251217_y11m_640_b16_e40_afterpad11_A4_S2?
# ✅ 학습 완료!

# %%
# =========================
# 4) best.pt 로드 + 검증 (항상 data 명시)
# =========================
best_pt = RUN_DIR / "weights" / "best.pt"
assert best_pt.exists(), f"best.pt 없음: {best_pt}"

best_model = YOLO(str(best_pt))
metrics = best_model.val(data=str(DATA_YAML_PATH))

print(f"\n🎯 mAP@0.5:0.95: {metrics.box.map:.3f}")
print(f"🎯 mAP@0.5: {metrics.box.map50:.3f}")


# =========================
# 5) 테스트 이미지 예측 (저장 위치 고정)
# =========================
CONF_THRES = 0.25
IOU_THRES = 0.5

pred_results = best_model.predict(
    source=str(TEST_DIR),
    save=True,
    conf=CONF_THRES,
    iou=IOU_THRES,
    project=str(RUNS_DIR),
    name=run_name,
    exist_ok=True,
)

print("\n✅ 테스트 예측 완료:", RUN_DIR / "predict")


# =========================
# 6) results.csv 기반 최종 성능 확인 (있으면 출력)
# =========================
results_csv = RUN_DIR / "results.csv"
if results_csv.exists():
    results_df = pd.read_csv(results_csv)
    col = "metrics/mAP50-95(B)"
    if col in results_df.columns:
        final_map = results_df[col].iloc[-1]
        print(f"📊 results.csv 최종 mAP50-95(B): {final_map:.3f}")
    else:
        print("⚠️ results.csv 컬럼이 예상과 다름. columns:", list(results_df.columns))
else:
    print("⚠️ results.csv를 찾을 수 없습니다:", results_csv)
# Out:
# Ultralytics 8.3.239 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,087,086 parameters, 0 gradients, 68.0 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3884.6±455.3 MB/s, size: 1695.6 KB)
# val: Scanning /content/yolo_dataset/labels/val.cache... 131 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 131/131 179.7Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 1.9it/s 4.7s
#                    all        131        492      0.987      0.984      0.995      0.995
#                   1899         19         19      0.997          1      0.995      0.995
#                   2482         19         19      0.997          1      0.995      0.995
#                   3350         32         32      0.998          1      0.995      0.995
#                   3482         50         50      0.999          1      0.995      0.995
#                   3543         11         11      0.996          1      0.995      0.995
#                   3742          3          3      0.982          1      0.995      0.995
#                   3831          4          4       0.99          1      0.995      0.995
#                   4377          6          6       0.99          1      0.995      0.995
#                   4542          4          4      0.985          1      0.995      0.995
#                   5093          7          7      0.992          1      0.995      0.995
#                   5885          3          3      0.983          1      0.995      0.995
#                   6191          3          3      0.988          1      0.995      0.995
#                   6562          4          4      0.985          1      0.995      0.995
#                  10220          4          4      0.986          1      0.995      0.995
#                  12080          3          3      0.988          1      0.995      0.995
#                  12246          2          2      0.978          1      0.995      0.995
#                  12419          1          1      0.969          1      0.995      0.995
#                  12777          5          5      0.994          1      0.995      0.995
#                  13394          3          3      0.983          1      0.995      0.995
#                  13899          3          3      0.981          1      0.995      0.995
#                  16231          9          9      0.995          1      0.995      0.995
#                  16261         14         14      0.998          1      0.995      0.995
#                  16547         18         18      0.997          1      0.995      0.995
#                  16550         12         12      0.995          1      0.995      0.995
#                  16687          2          2      0.979          1      0.995      0.995
#                  18109          4          4      0.985          1      0.995      0.995
#                  18146          5          5          1      0.806      0.995      0.995
#                  18356          2          2      0.978          1      0.995      0.995
#                  19231          3          3      0.984          1      0.995      0.995
#                  19551          3          3      0.983          1      0.995      0.995
#                  19606          4          4      0.985          1      0.995      0.995
#                  19860          9          9      0.994          1      0.995      0.995
#                  20013          3          3      0.985          1      0.995      0.995
#                  20237         12         12      0.995          1      0.995      0.995
#                  20876          9          9      0.994          1      0.995      0.995
#                  21025          3          3      0.981          1      0.995      0.995
#                  21324          3          3      0.976          1      0.995      0.995
#                  21770          3          3      0.983          1      0.995      0.995
#                  22073          2          2      0.968          1      0.995      0.995
#                  22346         11         11      0.994          1      0.995      0.995
#                  22361          4          4      0.986          1      0.995      0.995
#                  22626          5          5       0.99          1      0.995      0.995
#                  23202          1          1          1          1      0.995      0.995
#                  23222          3          3      0.986          1      0.995      0.995
#                  24849          3          3      0.981          1      0.995      0.995
#                  25366          8          8      0.993          1      0.995      0.995
#                  25437          9          9      0.995          1      0.995      0.995
#                  25468          7          7      0.993          1      0.995      0.995
#                  27652          8          8      0.992          1      0.995      0.995
#                  27732          8          8      0.993          1      0.995      0.995
#                  27776          9          9      0.993          1      0.995      0.995
#                  27925          5          5      0.988          1      0.995      0.995
#                  27992          1          1      0.969          1      0.995      0.995
#                  28762          7          7      0.982          1      0.995      0.995
#                  29344          1          1      0.964          1      0.995      0.995
#                  29450          3          3      0.985          1      0.995      0.995
#                  29666         17         17      0.996          1      0.995      0.995
#                  29870          1          1      0.965          1      0.995      0.995
#                  30307          6          6       0.99          1      0.995      0.995
#                  31704          3          3      0.984          1      0.995      0.995
#                  31862          2          2      0.978          1      0.995      0.995
#                  31884         11         11      0.995          1      0.995      0.995
#                  32309          3          3      0.984          1      0.995      0.995
#                  33008          7          7      0.996          1      0.995      0.995
#                  33207          3          3      0.984          1      0.995      0.995
#                  33877          1          1          1          0      0.995      0.995
#                  33879          4          4      0.988          1      0.995      0.995
#                  34596          7          7      0.992          1      0.995      0.995
#                  35205         11         11      0.995          1      0.995      0.995
#                  36636          9          9      0.995          1      0.995      0.995
#                  38161          3          3      0.982          1      0.995      0.995
#                  41767          3          3      0.921          1      0.995      0.995
#                  44198          2          2      0.978          1      0.995      0.995
# Speed: 2.3ms preprocess, 19.4ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to /content/runs/detect/val
#
# 🎯 mAP@0.5:0.95: 0.995
# 🎯 mAP@0.5: 0.995
#
# image 1/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1.png: 640x512 1 1899, 1 16550, 1 24849, 1 27925, 54.8ms
# image 2/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/10.png: 640x512 1 1899, 1 16547, 1 21770, 1 29450, 28.3ms
# image 3/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/100.png: 640x512 1 1899, 1 16547, 1 18109, 1 33008, 28.3ms
# image 4/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1003.png: 640x512 1 3482, 1 16231, 1 27732, 1 34596, 28.3ms
# image 5/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1004.png: 640x512 1 3482, 1 16231, 1 27732, 1 34596, 28.3ms
# image 6/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1005.png: 640x512 1 3482, 1 16231, 1 27732, 1 34596, 28.3ms
# image 7/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1006.png: 640x512 1 3482, 1 20237, 1 25366, 1 25468, 28.3ms
# image 8/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1007.png: 640x512 1 3482, 1 20237, 1 25366, 1 25468, 28.2ms
# image 9/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1009.png: 640x512 1 3482, 1 16261, 1 22346, 1 25468, 28.3ms
# image 10/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1010.png: 640x512 1 3482, 1 16261, 1 22346, 1 25468, 28.3ms
# image 11/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1012.png: 640x512 1 1899, 1 16547, 1 24849, 1 27925, 28.3ms
# image 12/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1013.png: 640x512 1 1899, 1 16547, 1 24849, 1 27925, 28.3ms
# image 13/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1014.png: 640x512 1 1899, 1 16547, 1 24849, 1 27925, 28.3ms
# image 14/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1015.png: 640x512 1 3482, 1 20876, 1 30307, 1 35205, 28.2ms
# image 15/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1016.png: 640x512 1 3482, 1 20876, 1 30307, 1 35205, 28.2ms
# image 16/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1018.png: 640x512 1 3482, 1 27732, 1 29666, 1 30307, 28.3ms
# image 17/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1019.png: 640x512 1 3482, 1 27732, 1 29666, 1 30307, 28.2ms
# image 18/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/102.png: 640x512 1 1899, 1 16547, 1 18109, 1 33008, 28.3ms
# image 19/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1020.png: 640x512 1 3482, 1 27732, 1 29666, 1 30307, 28.3ms
# image 20/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1022.png: 640x512 1 1899, 1 16550, 1 29450, 1 33207, 28.2ms
# image 21/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1023.png: 640x512 1 1899, 1 16550, 1 29450, 1 33207, 28.2ms
# image 22/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1025.png: 640x512 1 3482, 1 16261, 1 20876, 1 28762, 28.2ms
# image 23/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1026.png: 640x512 1 3482, 1 16261, 1 20876, 1 28762, 28.3ms
# image 24/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1027.png: 640x512 1 3350, 1 13899, 1 16231, 28.2ms
# image 25/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1028.png: 640x512 1 3350, 1 13899, 1 16231, 28.2ms
# image 26/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1029.png: 640x512 1 3350, 1 13899, 1 16231, 28.2ms
# image 27/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1030.png: 640x512 1 3482, 1 27732, 1 34596, 1 35205, 28.2ms
# image 28/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1034.png: 640x512 1 3482, 1 19860, 1 28762, 1 36636, 28.3ms
# image 29/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1039.png: 640x512 1 3482, 1 16261, 1 25468, 1 28762, 28.2ms
# image 30/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/104.png: 640x512 1 3350, 1 18356, 1 21324, 28.2ms
# image 31/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1041.png: 640x512 1 3482, 1 16261, 1 25468, 1 28762, 28.2ms
# image 32/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1043.png: 640x512 1 3350, 1 18356, 1 35205, 28.2ms
# image 33/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1044.png: 640x512 1 3350, 1 18356, 1 35205, 28.2ms
# image 34/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1045.png: 640x512 1 3482, 1 20876, 1 28762, 1 29666, 28.2ms
# image 35/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1046.png: 640x512 1 3482, 1 20876, 1 28762, 1 29666, 28.2ms
# image 36/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1047.png: 640x512 1 3482, 1 20876, 1 28762, 1 29666, 28.2ms
# image 37/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1050.png: 640x512 1 2482, 1 5093, 1 22361, 1 22626, 28.2ms
# image 38/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1051.png: 640x512 1 2482, 1 4377, 1 5093, 1 23222, 28.2ms
# image 39/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1053.png: 640x512 1 2482, 1 4377, 1 5093, 1 23222, 28.2ms
# image 40/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1055.png: 640x512 1 3482, 1 27732, 1 29666, 1 31884, 28.2ms
# image 41/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1056.png: 640x512 1 3482, 1 27732, 1 29666, 1 31884, 28.3ms
# image 42/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1057.png: 640x512 1 2482, 1 4377, 1 12777, 1 25437, 28.3ms
# image 43/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1058.png: 640x512 1 2482, 1 4377, 1 12777, 1 25437, 28.2ms
# image 44/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1060.png: 640x512 1 2482, 1 13394, 1 22626, 1 25437, 28.3ms
# image 45/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1064.png: 640x512 1 3482, 1 20237, 1 25468, 1 34596, 28.2ms
# image 46/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1065.png: 640x512 1 3482, 1 20237, 1 25468, 1 34596, 28.3ms
# image 47/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1067.png: 640x512 1 3482, 1 16261, 1 27652, 1 31884, 28.4ms
# image 48/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1069.png: 640x512 1 1899, 1 16547, 1 21025, 1 21770, 28.3ms
# image 49/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1070.png: 640x512 1 1899, 1 16547, 1 21025, 1 21770, 28.3ms
# image 50/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1073.png: 640x512 1 3482, 1 22346, 1 27776, 1 36636, 28.3ms
# image 51/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1075.png: 640x512 1 3543, 1 4542, 1 16550, 1 29870, 28.2ms
# image 52/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1076.png: 640x512 1 3543, 1 4542, 1 16550, 1 29870, 28.3ms
# image 53/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1077.png: 640x512 1 3543, 1 4542, 1 16550, 1 29870, 28.2ms
# image 54/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1079.png: 640x512 1 3482, 1 20876, 1 22346, 1 29666, 28.3ms
# image 55/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/108.png: 640x512 1 2482, 1 12777, 1 22361, 1 25437, 28.2ms
# image 56/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1080.png: 640x512 1 3482, 1 20876, 1 22346, 1 29666, 28.3ms
# image 57/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1081.png: 640x512 1 1899, 1 16550, 1 21025, 1 44198, 28.2ms
# image 58/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1085.png: 640x512 1 3482, 1 16231, 1 20876, 1 25366, 28.2ms
# image 59/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1087.png: 640x512 1 3543, 1 10220, 1 16550, 1 31704, 28.3ms
# image 60/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1089.png: 640x512 1 3543, 1 10220, 1 16550, 1 31704, 28.3ms
# image 61/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/109.png: 640x512 1 3482, 1 19860, 1 25366, 1 35205, 28.3ms
# image 62/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1092.png: 640x512 1 1899, 1 16547, 1 33008, 1 44198, 28.2ms
# image 63/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1093.png: 640x512 1 3482, 1 16261, 1 19860, 1 34596, 28.3ms
# image 64/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1095.png: 640x512 1 3482, 1 16261, 1 19860, 1 34596, 28.3ms
# image 65/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1096.png: 640x512 1 3543, 1 6562, 1 16550, 1 27992, 28.3ms
# image 66/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1097.png: 640x512 1 3543, 1 6562, 1 16550, 1 27992, 28.2ms
# image 67/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1098.png: 640x512 1 3543, 1 6562, 1 16550, 1 27992, 28.2ms
# image 68/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/110.png: 640x512 1 3482, 1 19860, 1 25366, 1 35205, 28.2ms
# image 69/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1100.png: 640x512 1 3482, 1 27776, 1 31884, 1 36636, 28.3ms
# image 70/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1101.png: 640x512 1 3482, 1 27776, 1 31884, 1 36636, 28.2ms
# image 71/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1105.png: 640x512 1 3482, 1 22346, 1 27732, 1 35205, 28.2ms
# image 72/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1109.png: 640x512 1 3482, 1 16261, 1 27652, 1 28762, 28.2ms
# image 73/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1111.png: 640x512 1 3482, 1 27652, 1 28762, 1 29666, 28.3ms
# image 74/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1114.png: 640x512 1 3482, 1 27652, 1 30307, 1 35205, 28.3ms
# image 75/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1115.png: 640x512 1 3482, 1 27652, 1 30307, 1 35205, 28.3ms
# image 76/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1116.png: 640x512 1 3482, 1 27652, 1 30307, 1 35205, 28.2ms
# image 77/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1118.png: 640x512 1 3543, 1 6562, 1 16547, 1 29870, 28.2ms
# image 78/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1119.png: 640x512 1 3543, 1 6562, 1 16547, 1 29870, 28.2ms
# image 79/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/112.png: 640x512 1 3543, 1 10220, 1 16550, 1 33008, 28.3ms
# image 80/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1121.png: 640x512 1 3482, 1 25468, 1 28762, 1 29666, 28.3ms
# image 81/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1123.png: 640x512 1 3482, 1 16261, 1 25366, 1 27732, 28.3ms
# image 82/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1125.png: 640x512 1 3482, 1 16261, 1 25366, 1 27732, 28.3ms
# image 83/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1126.png: 640x512 1 3482, 1 16261, 1 20876, 1 31884, 28.3ms
# image 84/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1129.png: 640x512 1 3482, 1 20237, 1 22346, 1 27732, 28.3ms
# image 85/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/113.png: 640x512 1 3543, 1 10220, 1 16550, 1 33008, 28.3ms
# image 86/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1135.png: 640x512 1 1899, 1 16550, 1 18109, 1 33008, 28.2ms
# image 87/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1136.png: 640x512 1 1899, 1 16550, 1 18109, 1 33008, 28.3ms
# image 88/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1138.png: 640x512 1 3482, 1 20237, 1 27652, 1 34596, 28.2ms
# image 89/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/114.png: 640x512 1 3543, 1 10220, 1 16550, 1 33008, 27.6ms
# image 90/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1140.png: 640x512 1 3482, 1 20237, 1 27652, 1 34596, 28.9ms
# image 91/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1141.png: 640x512 1 2482, 1 12080, 1 23222, 1 25437, 28.2ms
# image 92/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1142.png: 640x512 1 2482, 1 12080, 1 23222, 1 25437, 28.3ms
# image 93/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1143.png: 640x512 1 2482, 1 12080, 1 23222, 1 25437, 28.3ms
# image 94/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1144.png: 640x512 1 3482, 1 16261, 1 25468, 1 31884, 28.2ms
# image 95/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1148.png: 640x512 1 3350, 1 16231, 1 41767, 28.3ms
# image 96/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1149.png: 640x512 1 3350, 1 16231, 1 41767, 28.2ms
# image 97/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/115.png: 640x512 1 3482, 1 25366, 1 27732, 1 36636, 28.2ms
# image 98/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1150.png: 640x512 1 3482, 1 27776, 1 29666, 1 34596, 27.7ms
# image 99/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1153.png: 640x512 1 3482, 1 16231, 1 19860, 1 22346, 27.6ms
# image 100/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1154.png: 640x512 1 3482, 1 16231, 1 19860, 1 22346, 27.6ms
# image 101/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1155.png: 640x512 1 3482, 1 16231, 1 19860, 1 22346, 28.8ms
# image 102/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1156.png: 640x512 1 3350, 1 13899, 1 16261, 28.8ms
# image 103/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1157.png: 640x512 1 3350, 1 13899, 1 16261, 28.2ms
# image 104/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1158.png: 640x512 1 3350, 1 13899, 1 16261, 26.6ms
# image 105/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1159.png: 640x512 1 3350, 1 16231, 1 18356, 26.1ms
# image 106/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1161.png: 640x512 1 3350, 1 16231, 1 18356, 26.0ms
# image 107/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1163.png: 640x512 1 3543, 1 10220, 1 16550, 1 29450, 26.1ms
# image 108/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1164.png: 640x512 1 3543, 1 10220, 1 16550, 1 29450, 26.1ms
# image 109/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1166.png: 640x512 1 3482, 1 25366, 1 25468, 1 36636, 26.1ms
# image 110/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1167.png: 640x512 1 3482, 1 25366, 1 25468, 1 36636, 26.1ms
# image 111/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1168.png: 640x512 1 3482, 1 25468, 1 29666, 1 30307, 26.1ms
# image 112/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1170.png: 640x512 1 3482, 1 25468, 1 29666, 1 30307, 26.0ms
# image 113/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1171.png: 640x512 1 3543, 1 4542, 1 10220, 1 16547, 26.1ms
# image 114/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1173.png: 640x512 1 3543, 1 4542, 1 10220, 1 16547, 26.1ms
# image 115/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1174.png: 640x512 1 3482, 1 27652, 1 29666, 1 30307, 26.1ms
# image 116/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1176.png: 640x512 1 3482, 1 27652, 1 29666, 1 30307, 26.1ms
# image 117/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1178.png: 640x512 1 3482, 1 20237, 1 27776, 1 31884, 26.1ms
# image 118/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/118.png: 640x512 1 3350, 1 13899, 1 16687, 26.1ms
# image 119/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1180.png: 640x512 1 3350, 1 19231, 1 21324, 26.1ms
# image 120/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1184.png: 640x512 1 1899, 1 16547, 1 21025, 1 24849, 27.3ms
# image 121/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1185.png: 640x512 1 1899, 1 16547, 1 21025, 1 24849, 28.9ms
# image 122/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1186.png: 640x512 1 2482, 1 4377, 1 5093, 1 19551, 28.2ms
# image 123/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1187.png: 640x512 1 2482, 1 4377, 1 5093, 1 19551, 28.2ms
# image 124/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1189.png: 640x512 1 2482, 1 3742, 1 12080, 1 22626, 28.2ms
# image 125/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/119.png: 640x512 1 3350, 1 13899, 1 16687, 28.2ms
# image 126/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1190.png: 640x512 1 2482, 1 3742, 1 12080, 1 22626, 28.3ms
# image 127/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1191.png: 640x512 1 2482, 1 3742, 1 12080, 1 22626, 28.3ms
# image 128/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1192.png: 640x512 1 1899, 1 16550, 1 24849, 1 33008, 28.3ms
# image 129/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1194.png: 640x512 1 1899, 1 16550, 1 24849, 1 33008, 28.3ms
# image 130/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1196.png: 640x512 1 3482, 1 27776, 1 28762, 1 35205, 28.2ms
# image 131/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1197.png: 640x512 1 3482, 1 27776, 1 28762, 1 35205, 28.2ms
# image 132/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1198.png: 640x512 1 3482, 1 20237, 1 27776, 1 28762, 28.3ms
# image 133/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1199.png: 640x512 1 3482, 1 20237, 1 27776, 1 28762, 28.2ms
# image 134/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/120.png: 640x512 1 3350, 1 13899, 1 16687, 28.2ms
# image 135/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1201.png: 640x512 1 3543, 1 12246, 1 16547, 1 21025, 28.3ms
# image 136/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1204.png: 640x512 1 3350, 1 22073, 1 32309, 28.2ms
# image 137/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1206.png: 640x512 1 3350, 1 22073, 1 32309, 28.2ms
# image 138/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1207.png: 640x512 1 3482, 1 16231, 1 22346, 1 27776, 26.6ms
# image 139/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1209.png: 640x512 1 3482, 1 16231, 1 22346, 1 27776, 26.1ms
# image 140/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1210.png: 640x512 1 3482, 1 20876, 1 34596, 1 35205, 26.1ms
# image 141/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1212.png: 640x512 1 3482, 1 20876, 1 34596, 1 35205, 26.0ms
# image 142/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1213.png: 640x512 1 2482, 1 5885, 1 22626, 1 25437, 26.1ms
# image 143/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1214.png: 640x512 1 2482, 1 5885, 1 22626, 1 25437, 26.1ms
# image 144/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1216.png: 640x512 1 3543, 1 10220, 1 16550, 1 27925, 26.1ms
# image 145/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1219.png: 640x512 1 3543, 1 10220, 1 16550, 1 29344, 26.1ms
# image 146/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/122.png: 640x512 1 3482, 1 25366, 1 25468, 1 29666, 26.1ms
# image 147/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1220.png: 640x512 1 3543, 1 10220, 1 16550, 1 29344, 26.1ms
# image 148/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1222.png: 640x512 1 3482, 1 25366, 1 27652, 1 36636, 26.1ms
# image 149/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1224.png: 640x512 1 3482, 1 25366, 1 27652, 1 36636, 26.0ms
# image 150/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1226.png: 640x512 1 3482, 1 19860, 1 31884, 1 35205, 26.1ms
# image 151/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1227.png: 640x512 1 3482, 1 19860, 1 31884, 1 35205, 26.1ms
# image 152/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1232.png: 640x512 1 3482, 1 20876, 1 29666, 1 31884, 26.1ms
# image 153/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1235.png: 640x512 1 1899, 1 16547, 1 21770, 1 33008, 26.0ms
# image 154/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1237.png: 640x512 1 1899, 1 16547, 1 31704, 1 44198, 26.1ms
# image 155/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1238.png: 640x512 1 1899, 1 16547, 1 31704, 1 44198, 27.5ms
# image 156/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1239.png: 640x512 1 1899, 1 16547, 1 31704, 1 44198, 28.9ms
# image 157/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/124.png: 640x512 1 1899, 1 16550, 1 21025, 1 21770, 28.2ms
# image 158/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1242.png: 640x512 1 1899, 1 16550, 1 29344, 1 44198, 28.2ms
# image 159/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1243.png: 640x512 1 3482, 1 27732, 1 30307, 1 35205, 28.2ms
# image 160/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1244.png: 640x512 1 3482, 1 27732, 1 30307, 1 35205, 28.2ms
# image 161/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1245.png: 640x512 1 3482, 1 27732, 1 30307, 1 35205, 28.2ms
# image 162/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1246.png: 640x512 1 3482, 1 16261, 1 27776, 1 34596, 28.3ms
# image 163/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1248.png: 640x512 1 3482, 1 16261, 1 27776, 1 34596, 28.2ms
# image 164/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/125.png: 640x512 1 1899, 1 16550, 1 21025, 1 21770, 28.3ms
# image 165/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1250.png: 640x512 1 2482, 1 4377, 1 5093, 1 12777, 28.2ms
# image 166/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1251.png: 640x512 1 2482, 1 4377, 1 5093, 1 12777, 28.2ms
# image 167/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1252.png: 640x512 1 3482, 1 20876, 1 29666, 1 30307, 28.2ms
# image 168/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1254.png: 640x512 1 3482, 1 20876, 1 29666, 1 30307, 28.2ms
# image 169/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1256.png: 640x512 1 1899, 1 16550, 1 19606, 1 31704, 28.2ms
# image 170/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/126.png: 640x512 1 1899, 1 16550, 1 21025, 1 21770, 28.2ms
# image 171/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1261.png: 640x512 1 3482, 1 16231, 1 22346, 1 27652, 28.2ms
# image 172/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1262.png: 640x512 1 3482, 1 16231, 1 22346, 1 27652, 28.2ms
# image 173/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1263.png: 640x512 1 3482, 1 16231, 1 22346, 1 27652, 28.2ms
# image 174/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1264.png: 640x512 1 3350, 1 31862, 1 36636, 28.2ms
# image 175/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1265.png: 640x512 1 3350, 1 31862, 1 36636, 28.3ms
# image 176/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1266.png: 640x512 1 3350, 1 31862, 1 36636, 28.2ms
# image 177/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1269.png: 640x512 1 3350, 1 13899, 1 36636, 28.2ms
# image 178/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/127.png: 640x512 1 2482, 1 5093, 1 6191, 1 22361, 28.2ms
# image 179/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1270.png: 640x512 1 1899, 1 16547, 1 18109, 1 27925, 28.3ms
# image 180/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1272.png: 640x512 1 1899, 1 16547, 1 18109, 1 27925, 28.2ms
# image 181/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1273.png: 640x512 1 2482, 1 6191, 1 13394, 1 25437, 28.3ms
# image 182/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1274.png: 640x512 1 2482, 1 6191, 1 13394, 1 25437, 28.3ms
# image 183/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1278.png: 640x512 1 3350, 1 3831, 1 38161, 28.2ms
# image 184/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1279.png: 640x512 1 1899, 1 16550, 1 21770, 1 31704, 28.2ms
# image 185/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/128.png: 640x512 1 2482, 1 5093, 1 6191, 1 22361, 27.1ms
# image 186/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1280.png: 640x512 1 1899, 1 16550, 1 21770, 1 31704, 26.6ms
# image 187/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1282.png: 640x512 1 2482, 1 3742, 1 13394, 1 19551, 26.6ms
# image 188/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1284.png: 640x512 1 2482, 1 3742, 1 13394, 1 19551, 26.6ms
# image 189/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/129.png: 640x512 1 2482, 1 5093, 1 6191, 1 22361, 26.6ms
# image 190/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1290.png: 640x512 1 1899, 1 16547, 1 18109, 1 29344, 26.6ms
# image 191/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1293.png: 640x512 1 3482, 1 20237, 1 27776, 1 30307, 26.6ms
# image 192/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1294.png: 640x512 1 3482, 1 27652, 1 34596, 1 35205, 26.6ms
# image 193/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1295.png: 640x512 1 3482, 1 27652, 1 34596, 1 35205, 26.6ms
# image 194/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1296.png: 640x512 1 3482, 1 27652, 1 34596, 1 35205, 26.6ms
# image 195/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1297.png: 640x512 1 3543, 1 4542, 1 12419, 1 16547, 26.6ms
# image 196/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1298.png: 640x512 1 3543, 1 4542, 1 12419, 1 16547, 26.6ms
# image 197/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/13.png: 640x512 1 3350, 1 16231, 1 33879, 26.6ms
# image 198/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/130.png: 640x512 1 3482, 1 27776, 1 30307, 1 36636, 26.6ms
# image 199/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1300.png: 640x512 1 3482, 1 27652, 1 29666, 1 31884, 28.3ms
# image 200/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1302.png: 640x512 1 3482, 1 27652, 1 29666, 1 31884, 28.2ms
# image 201/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1305.png: 640x512 1 1899, 1 16550, 1 27925, 1 44198, 28.2ms
# image 202/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1309.png: 640x512 1 3482, 1 27732, 1 28762, 1 29666, 28.2ms
# image 203/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1311.png: 640x512 1 3482, 1 27732, 1 28762, 1 29666, 28.3ms
# image 204/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1312.png: 640x512 1 2482, 1 5093, 1 5885, 1 22626, 28.2ms
# image 205/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1315.png: 640x512 1 3350, 1 16687, 1 19231, 28.3ms
# image 206/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1316.png: 640x512 1 3350, 1 16687, 1 19231, 28.3ms
# image 207/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/132.png: 640x512 1 3482, 1 27776, 1 30307, 1 36636, 28.3ms
# image 208/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1322.png: 640x512 1 2482, 1 4377, 1 5093, 1 6191, 28.2ms
# image 209/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1323.png: 640x512 1 2482, 1 4377, 1 5093, 1 6191, 26.6ms
# image 210/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1326.png: 640x512 1 3350, 1 18356, 1 20237, 26.1ms
# image 211/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1327.png: 640x512 1 1899, 1 16547, 1 29450, 1 44198, 26.1ms
# image 212/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1328.png: 640x512 1 1899, 1 16547, 1 29450, 1 44198, 26.1ms
# image 213/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1329.png: 640x512 1 1899, 1 16547, 1 29450, 1 44198, 26.0ms
# image 214/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1330.png: 640x512 1 3482, 1 25468, 1 34596, 1 35205, 26.1ms
# image 215/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1331.png: 640x512 1 3482, 1 25468, 1 34596, 1 35205, 26.1ms
# image 216/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1332.png: 640x512 1 3482, 1 25468, 1 34596, 1 35205, 26.1ms
# image 217/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1333.png: 640x512 1 3350, 1 20013, 1 36636, 26.1ms
# image 218/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1337.png: 640x512 1 1899, 1 16547, 1 18109, 1 29450, 26.1ms
# image 219/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/134.png: 640x512 1 3482, 1 27652, 1 31884, 1 35205, 26.2ms
# image 220/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1340.png: 640x512 1 1899, 1 16547, 1 24849, 1 31704, 26.1ms
# image 221/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1345.png: 640x512 1 3482, 1 25468, 1 29666, 1 31884, 26.1ms
# image 222/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1347.png: 640x512 1 3482, 1 25468, 1 29666, 1 31884, 26.1ms
# image 223/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1348.png: 640x512 1 3350, 1 22073, 1 31862, 26.1ms
# image 224/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/135.png: 640x512 1 3482, 1 27652, 1 31884, 1 35205, 28.4ms
# image 225/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1350.png: 640x512 1 3350, 1 22073, 1 31862, 28.3ms
# image 226/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1353.png: 640x512 1 3482, 1 16231, 1 27776, 1 34596, 28.3ms
# image 227/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1354.png: 640x512 1 3482, 1 20876, 1 30307, 1 36636, 28.2ms
# image 228/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1355.png: 640x512 1 3482, 1 20876, 1 30307, 1 36636, 28.3ms
# image 229/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1357.png: 640x512 1 3543, 1 6562, 1 12419, 1 16547, 28.3ms
# image 230/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1358.png: 640x512 1 3543, 1 4542, 1 6562, 1 12419, 1 16547, 28.3ms
# image 231/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1359.png: 640x512 1 3543, 1 6562, 1 12419, 1 16547, 28.2ms
# image 232/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/136.png: 640x512 1 1899, 1 16550, 1 33008, 1 44198, 28.2ms
# image 233/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1361.png: 640x512 1 3350, 1 19231, 1 29666, 28.3ms
# image 234/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1363.png: 640x512 1 3350, 1 16261, 1 33879, 28.3ms
# image 235/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1366.png: 640x512 1 3482, 1 22346, 1 27652, 1 29666, 28.2ms
# image 236/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1367.png: 640x512 1 3482, 1 22346, 1 27652, 1 29666, 28.2ms
# image 237/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1369.png: 640x512 1 3482, 1 16261, 1 19860, 1 22346, 27.6ms
# image 238/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1371.png: 640x512 1 3482, 1 16261, 1 19860, 1 22346, 27.1ms
# image 239/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1372.png: 640x512 1 2482, 1 3742, 1 5885, 1 22626, 27.1ms
# image 240/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1376.png: 640x512 1 1899, 1 16550, 1 33008, 1 33207, 27.1ms
# image 241/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1377.png: 640x512 1 1899, 1 16550, 1 33008, 1 33207, 27.1ms
# image 242/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1378.png: 640x512 1 3482, 1 19860, 1 22346, 1 35205, 27.1ms
# image 243/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1379.png: 640x512 1 3482, 1 19860, 1 22346, 1 35205, 27.1ms
# image 244/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1381.png: 640x512 1 3350, 1 21324, 1 32309, 27.1ms
# image 245/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1384.png: 640x512 1 3482, 1 20237, 1 25366, 1 27776, 27.1ms
# image 246/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1385.png: 640x512 1 3482, 1 20237, 1 25366, 1 27776, 27.1ms
# image 247/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1386.png: 640x512 1 3482, 1 20237, 1 25366, 1 27776, 27.1ms
# image 248/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1387.png: 640x512 1 3482, 1 20237, 1 20876, 1 22346, 27.1ms
# image 249/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/139.png: 640x512 1 3482, 1 25468, 1 31884, 1 35205, 26.1ms
# image 250/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1390.png: 640x512 1 2482, 1 22361, 1 22626, 1 25437, 25.6ms
# image 251/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1392.png: 640x512 1 2482, 1 22361, 1 22626, 1 25437, 25.6ms
# image 252/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1393.png: 640x512 1 3482, 1 16261, 1 22346, 1 27776, 25.6ms
# image 253/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1395.png: 640x512 1 3482, 1 16261, 1 22346, 1 27776, 25.6ms
# image 254/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1396.png: 640x512 1 2482, 1 5093, 1 13394, 1 19551, 25.6ms
# image 255/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/140.png: 640x512 1 3482, 1 25468, 1 31884, 1 35205, 25.6ms
# image 256/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1401.png: 640x512 1 3482, 1 22346, 1 25468, 1 29666, 25.6ms
# image 257/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1402.png: 640x512 1 3350, 1 20237, 1 33879, 25.6ms
# image 258/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1404.png: 640x512 1 3350, 1 20237, 1 33879, 25.6ms
# image 259/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1407.png: 640x512 1 3350, 1 33879, 1 38161, 25.6ms
# image 260/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1408.png: 640x512 1 1899, 1 16547, 1 21025, 1 33207, 25.6ms
# image 261/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1411.png: 640x512 1 3482, 1 27652, 1 30307, 1 36636, 25.6ms
# image 262/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1413.png: 640x512 1 3482, 1 27652, 1 30307, 1 36636, 25.6ms
# image 263/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1414.png: 640x512 1 3543, 1 10220, 1 16547, 1 27925, 25.6ms
# image 264/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1418.png: 640x512 1 1899, 1 10223, 1 16550, 1 31704, 25.6ms
# image 265/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/142.png: 640x512 1 1899, 1 16547, 1 21025, 1 44198, 25.6ms
# image 266/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1420.png: 640x512 1 3350, 1 16687, 1 41767, 25.7ms
# image 267/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1421.png: 640x512 1 3350, 1 16687, 1 41767, 27.2ms
# image 268/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1424.png: 640x512 1 3482, 1 27776, 1 31884, 1 35205, 28.1ms
# image 269/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1425.png: 640x512 1 3482, 1 27776, 1 31884, 1 35205, 28.2ms
# image 270/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1429.png: 640x512 1 3543, 1 10220, 1 16547, 1 29344, 28.3ms
# image 271/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/143.png: 640x512 1 1899, 1 16547, 1 21025, 1 44198, 28.2ms
# image 272/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1431.png: 640x512 1 3543, 1 10220, 1 16547, 1 29344, 28.2ms
# image 273/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1433.png: 640x512 1 3350, 1 32309, 1 38161, 28.3ms
# image 274/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1435.png: 640x512 1 3350, 1 13899, 1 20237, 28.2ms
# image 275/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1436.png: 640x512 1 3350, 1 13899, 1 20237, 28.2ms
# image 276/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1438.png: 640x512 1 3543, 1 6562, 1 12246, 1 16547, 28.3ms
# image 277/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1439.png: 640x512 1 3543, 1 6562, 1 12246, 1 16547, 28.2ms
# image 278/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1441.png: 640x512 1 3482, 1 22346, 1 27732, 1 36636, 28.2ms
# image 279/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1442.png: 640x512 1 3482, 1 22346, 1 27732, 1 36636, 28.2ms
# image 280/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1444.png: 640x512 1 2482, 1 3742, 1 4377, 1 23222, 28.3ms
# image 281/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1446.png: 640x512 1 2482, 1 3742, 1 4377, 1 23222, 26.6ms
# image 282/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1447.png: 640x512 1 3543, 1 10220, 1 16547, 1 29450, 26.1ms
# image 283/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1449.png: 640x512 1 3543, 1 10220, 1 16547, 1 29450, 26.1ms
# image 284/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1450.png: 640x512 1 2482, 1 12777, 1 13394, 1 25437, 26.1ms
# image 285/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1452.png: 640x512 1 2482, 1 12777, 1 13394, 1 25437, 26.1ms
# image 286/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1453.png: 640x512 1 3350, 1 16687, 1 18356, 26.1ms
# image 287/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/1455.png: 640x512 1 3350, 1 16687, 1 18356, 26.0ms
# ...
# image 735/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/822.png: 640x512 1 2482, 1 3742, 1 4377, 1 19551, 26.1ms
# image 736/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/826.png: 640x512 1 3350, 1 18146, 1 38161, 28.3ms
# image 737/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/828.png: 640x512 1 3350, 1 18146, 1 38161, 28.3ms
# image 738/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/829.png: 640x512 1 3482, 1 27776, 1 28762, 1 36636, 28.3ms
# image 739/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/83.png: 640x512 1 2482, 1 3742, 1 19551, 1 22361, 28.2ms
# image 740/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/830.png: 640x512 1 3482, 1 27776, 1 28762, 1 36636, 28.2ms
# image 741/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/831.png: 640x512 1 3482, 1 27776, 1 28762, 1 36636, 28.2ms
# image 742/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/832.png: 640x512 1 1899, 1 16547, 1 18109, 1 21025, 28.2ms
# image 743/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/838.png: 640x512 1 1899, 1 16547, 1 27925, 1 33207, 28.3ms
# image 744/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/842.png: 640x512 1 3482, 1 16261, 1 27732, 1 34596, 28.3ms
# image 745/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/85.png: 640x512 1 1899, 1 16547, 1 21770, 1 29344, 28.2ms
# image 746/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/851.png: 640x512 1 2482, 1 3742, 1 22361, 1 22626, 28.3ms
# image 747/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/855.png: 640x512 1 2482, 1 3742, 1 4377, 1 12777, 28.3ms
# image 748/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/857.png: 640x512 1 3350, 1 16261, 1 31862, 28.2ms
# image 749/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/858.png: 640x512 1 3350, 1 16261, 1 31862, 28.2ms
# image 750/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/86.png: 640x512 1 1899, 1 16547, 1 21770, 1 29344, 28.3ms
# image 751/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/861.png: 640x512 1 2482, 1 12080, 1 19551, 1 25437, 28.3ms
# image 752/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/862.png: 640x512 1 3482, 1 25468, 1 34596, 1 36636, 28.2ms
# image 753/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/864.png: 640x512 1 3482, 1 25468, 1 34596, 1 36636, 28.2ms
# image 754/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/866.png: 640x512 1 3350, 1 3831, 1 16687, 28.3ms
# image 755/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/867.png: 640x512 1 3350, 1 3831, 1 16687, 1 35205, 28.2ms
# image 756/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/868.png: 640x512 1 3482, 1 16231, 1 27652, 1 31884, 28.2ms
# image 757/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/869.png: 640x512 1 3482, 1 16231, 1 27652, 1 31884, 28.2ms
# image 758/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/870.png: 640x512 1 3482, 1 16231, 1 27652, 1 31884, 28.3ms
# image 759/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/873.png: 640x512 1 3350, 1 16687, 1 18146, 26.1ms
# image 760/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/874.png: 640x512 1 3482, 1 16231, 1 20876, 1 31884, 25.6ms
# image 761/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/875.png: 640x512 1 3482, 1 16231, 1 20876, 1 31884, 25.6ms
# image 762/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/878.png: 640x512 1 3482, 1 27652, 1 34596, 1 36636, 25.6ms
# image 763/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/879.png: 640x512 1 3482, 1 27652, 1 34596, 1 36636, 25.6ms
# image 764/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/88.png: 640x512 1 1899, 1 16550, 1 18109, 1 31704, 25.6ms
# image 765/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/880.png: 640x512 1 2482, 1 5093, 1 13394, 1 23222, 25.6ms
# image 766/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/882.png: 640x512 1 2482, 1 5093, 1 13394, 1 23222, 25.6ms
# image 767/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/883.png: 640x512 1 3482, 1 16231, 1 25468, 1 28762, 25.6ms
# image 768/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/886.png: 640x512 1 3350, 1 31862, 1 35205, 25.6ms
# image 769/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/888.png: 640x512 1 3350, 1 31862, 1 35205, 25.5ms
# image 770/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/889.png: 640x512 1 3482, 1 16231, 1 20876, 1 28762, 25.6ms
# image 771/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/89.png: 640x512 1 1899, 1 16550, 1 18109, 1 31704, 25.6ms
# image 772/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/891.png: 640x512 1 3482, 1 16231, 1 20876, 1 28762, 25.6ms
# image 773/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/894.png: 640x512 1 3482, 1 20876, 1 25366, 1 36636, 25.6ms
# image 774/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/895.png: 640x512 1 3543, 1 10220, 1 16550, 1 21025, 25.6ms
# image 775/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/896.png: 640x512 1 3543, 1 10220, 1 16550, 1 21025, 25.6ms
# image 776/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/897.png: 640x512 1 3543, 1 10220, 1 16550, 1 21025, 25.6ms
# image 777/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/898.png: 640x512 1 3543, 1 12246, 1 16547, 1 27925, 28.9ms
# image 778/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/9.png: 640x512 1 3482, 1 20237, 1 22346, 1 27652, 28.2ms
# image 779/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/90.png: 640x512 1 1899, 1 16550, 1 18109, 1 31704, 28.2ms
# image 780/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/900.png: 640x512 1 3543, 1 12246, 1 16547, 1 27925, 28.2ms
# image 781/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/904.png: 640x512 1 3482, 1 20237, 1 27732, 1 30307, 28.2ms
# image 782/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/906.png: 640x512 1 3482, 1 20237, 1 27732, 1 30307, 28.3ms
# image 783/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/908.png: 640x512 1 3350, 1 20237, 1 31862, 28.3ms
# image 784/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/91.png: 640x512 1 1899, 1 16547, 1 19606, 1 27925, 28.3ms
# image 785/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/910.png: 640x512 1 3482, 1 25366, 1 27776, 1 29666, 27.7ms
# image 786/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/912.png: 640x512 1 3482, 1 25366, 1 27776, 1 29666, 28.3ms
# image 787/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/914.png: 640x512 1 3350, 1 13899, 1 35205, 28.3ms
# image 788/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/915.png: 640x512 1 3350, 1 13899, 1 35205, 28.2ms
# image 789/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/916.png: 640x512 1 3482, 1 16231, 1 25366, 1 27732, 28.2ms
# image 790/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/919.png: 640x512 1 3482, 1 27732, 1 30307, 1 36636, 28.2ms
# image 791/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/920.png: 640x512 1 3482, 1 27732, 1 30307, 1 36636, 28.2ms
# image 792/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/923.png: 640x512 1 3482, 1 16261, 1 20876, 1 25366, 28.2ms
# image 793/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/925.png: 640x512 1 3482, 1 16231, 1 19860, 1 34596, 28.2ms
# image 794/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/927.png: 640x512 1 3482, 1 16231, 1 19860, 1 34596, 28.3ms
# image 795/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/929.png: 640x512 1 3482, 1 16231, 1 25468, 1 31884, 28.3ms
# image 796/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/930.png: 640x512 1 3482, 1 16231, 1 25468, 1 31884, 28.2ms
# image 797/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/931.png: 640x512 1 1899, 1 16550, 1 19606, 1 29344, 28.2ms
# image 798/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/932.png: 640x512 1 1899, 1 16550, 1 19606, 1 29344, 28.2ms
# image 799/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/933.png: 640x512 1 1899, 1 16550, 1 19606, 1 29344, 27.7ms
# image 800/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/936.png: 640x512 1 2482, 1 4377, 1 19551, 1 25437, 27.1ms
# image 801/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/937.png: 640x512 1 2482, 1 3742, 1 4377, 1 6191, 27.1ms
# image 802/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/938.png: 640x512 1 2482, 1 3742, 1 4377, 1 6191, 27.1ms
# image 803/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/940.png: 640x512 1 3350, 1 16231, 1 18146, 27.1ms
# image 804/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/941.png: 640x512 1 3350, 1 16231, 1 18146, 27.1ms
# image 805/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/942.png: 640x512 1 3350, 1 16231, 1 18146, 27.1ms
# image 806/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/945.png: 640x512 1 3482, 1 19860, 1 20237, 1 25366, 27.1ms
# image 807/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/947.png: 640x512 1 3482, 1 16231, 1 27652, 1 28762, 27.1ms
# image 808/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/948.png: 640x512 1 3482, 1 16231, 1 27652, 1 28762, 27.1ms
# image 809/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/949.png: 640x512 1 3482, 1 16261, 1 20876, 1 30307, 27.1ms
# image 810/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/95.png: 640x512 1 3350, 1 29666, 1 32309, 27.1ms
# image 811/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/950.png: 640x512 1 3482, 1 16261, 1 20876, 1 30307, 27.1ms
# image 812/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/951.png: 640x512 1 3482, 1 16261, 1 20876, 1 30307, 27.1ms
# image 813/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/952.png: 640x512 1 3482, 1 16261, 1 25468, 1 30307, 27.1ms
# image 814/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/953.png: 640x512 1 3482, 1 16261, 1 25468, 1 30307, 27.1ms
# image 815/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/954.png: 640x512 1 3482, 1 16261, 1 25468, 1 30307, 27.1ms
# image 816/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/956.png: 640x512 1 1899, 1 16550, 1 19606, 1 27925, 27.1ms
# image 817/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/957.png: 640x512 1 1899, 1 16550, 1 19606, 1 27925, 27.1ms
# image 818/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/962.png: 640x512 1 1899, 1 16550, 1 19606, 1 29450, 27.1ms
# image 819/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/966.png: 640x512 1 1899, 1 16547, 1 18109, 1 31704, 27.1ms
# image 820/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/967.png: 640x512 1 3350, 1 29666, 1 41767, 27.1ms
# image 821/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/968.png: 640x512 1 3350, 1 29666, 1 41767, 27.2ms
# image 822/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/97.png: 640x512 1 1899, 1 16547, 1 19606, 1 29344, 27.9ms
# image 823/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/972.png: 640x512 1 1899, 1 16550, 1 21770, 1 27925, 28.3ms
# image 824/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/973.png: 640x512 1 1899, 1 16550, 1 21770, 1 29344, 27.6ms
# image 825/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/974.png: 640x512 1 1899, 1 16550, 1 21770, 1 29344, 27.6ms
# image 826/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/975.png: 640x512 1 1899, 1 16550, 1 21770, 1 29344, 27.1ms
# image 827/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/979.png: 640x512 1 3350, 1 18356, 1 22073, 27.1ms
# image 828/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/980.png: 640x512 1 3350, 1 18356, 1 22073, 27.1ms
# image 829/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/982.png: 640x512 1 2482, 1 3742, 1 13394, 1 23222, 27.1ms
# image 830/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/983.png: 640x512 1 2482, 1 3742, 1 13394, 1 23222, 27.1ms
# image 831/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/984.png: 640x512 1 2482, 1 3742, 1 13394, 1 23222, 27.1ms
# image 832/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/985.png: 640x512 1 1899, 1 16547, 1 24849, 1 29450, 27.1ms
# image 833/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/986.png: 640x512 1 1899, 1 16547, 1 24849, 1 29450, 27.1ms
# image 834/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/988.png: 640x512 1 3482, 1 19860, 1 22346, 1 36636, 27.1ms
# image 835/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/989.png: 640x512 1 3482, 1 19860, 1 22346, 1 36636, 27.1ms
# image 836/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/990.png: 640x512 1 3482, 1 19860, 1 22346, 1 36636, 27.1ms
# image 837/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/991.png: 640x512 1 3543, 1 10220, 1 16547, 1 21025, 27.1ms
# image 838/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/993.png: 640x512 1 3543, 1 10220, 1 16547, 1 21025, 27.1ms
# image 839/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/994.png: 640x512 1 3482, 1 16261, 1 27652, 1 30307, 27.1ms
# image 840/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/996.png: 640x512 1 3482, 1 16261, 1 27652, 1 30307, 27.1ms
# image 841/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/997.png: 640x512 1 1899, 1 16550, 1 21770, 1 29450, 27.1ms
# image 842/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/998.png: 640x512 1 1899, 1 16550, 1 21770, 1 29450, 27.1ms
# image 843/843 /content/gdrive/MyDrive/AI-06_5team-Object-Detection/data/test_images/999.png: 640x512 1 1899, 1 16550, 1 21770, 1 29450, 27.1ms
# Speed: 2.1ms preprocess, 27.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to /content/gdrive/.shortcut-targets-by-id/1po9nINU9wzcKmM6FW0IqwLgoEDz32UTZ/AI-06_5team-Object-Detection/notebooks/yolo_runs/20251217_y11m_640_b16_e40_afterpad11_A4_S2?
#
# ✅ 테스트 예측 완료: /content/gdrive/.shortcut-targets-by-id/1po9nINU9wzcKmM6FW0IqwLgoEDz32UTZ/AI-06_5team-Object-Detection/notebooks/yolo_runs/20251217_y11m_640_b16_e40_afterpad11_A4_S2?/predict
# 📊 results.csv 최종 mAP50-95(B): 0.995

# %%
# 경로 재확인용
from ultralytics import YOLO
from pathlib import Path

# ✅ RUN_DIR / best.pt 재확인
RUN_DIR = Path(RUN_DIR)  # 혹시 문자열이면 Path로
best_pt = RUN_DIR / "weights" / "best.pt"
assert best_pt.exists(), f"best.pt 없음: {best_pt}"

# ✅ best_model 정의 (여기서 끝)
best_model = YOLO(str(best_pt))
print("✅ best_model loaded:", best_pt)
# Out:
# ✅ best_model loaded: /content/gdrive/.shortcut-targets-by-id/1po9nINU9wzcKmM6FW0IqwLgoEDz32UTZ/AI-06_5team-Object-Detection/notebooks/yolo_runs/20251217_y11m_640_b16_e40_afterpad11_A4_S2?/weights/best.pt

# %%
import os, glob, random
from pathlib import Path
import matplotlib.pyplot as plt
from PIL import Image
import cv2
import numpy as np
import yaml

# =========================
# 0) 유틸: names 로드 (cls_idx -> label 문자열)
# =========================
def load_names_from_data_yaml(data_yaml_path: Path):
    with open(data_yaml_path, "r", encoding="utf-8") as f:
        cfg = yaml.safe_load(f)
    names = cfg.get("names")
    if names is None:
        raise ValueError("data.yaml에 names가 없습니다.")
    # list 또는 dict 둘 다 대응
    if isinstance(names, dict):
        # key가 str일 수도 있으니 int->str fallback
        def get_name(i: int):
            return str(names.get(i, names.get(str(i), i)))
    else:
        def get_name(i: int):
            return str(names[i])
    return get_name


# =========================
# 1) 학습 결과 이미지: RUN_DIR에 있는 것만 자동 표시
# =========================
def show_training_artifacts(run_dir: Path, cols: int = 3):
    """
    RUN_DIR 내 학습 결과 이미지들을 있는 것만 자동으로 그리드로 표시
    """
    candidates = [
        "results.png",
        "confusion_matrix.png",
        "confusion_matrix_normalized.png",
        "BoxPR_curve.png",
        "BoxF1_curve.png",
        "BoxP_curve.png",
        "BoxR_curve.png",
        "labels.jpg",
        "labels_correlogram.jpg",
    ]

    images = [run_dir / fn for fn in candidates if (run_dir / fn).exists()]
    if not images:
        print("⚠️ 표시할 학습 아티팩트 이미지가 없습니다. (RUN_DIR 확인)", run_dir)
        return

    rows = (len(images) + cols - 1) // cols
    fig, axes = plt.subplots(rows, cols, figsize=(6 * cols, 5 * rows))
    axes = np.array(axes).reshape(-1)

    fig.suptitle(f"YOLO Training Artifacts\n{run_dir.name}", fontsize=14, fontweight="bold")

    for ax, img_path in zip(axes, images):
        img = Image.open(img_path)
        ax.imshow(img)
        ax.set_title(img_path.name.replace(".png", "").replace(".jpg", ""), fontsize=10)
        ax.axis("off")

    # 남는 축 비우기
    for ax in axes[len(images):]:
        ax.axis("off")

    plt.tight_layout()
    plt.show()


# =========================
# 2) Validation 샘플 예측 그리드
# =========================
def visualize_val_predictions(model, yolo_base_path: Path, num_samples: int = 9, conf: float = 0.25):
    """
    yolo_dataset/images/val 에서 샘플 뽑아 예측 결과 그리드 출력
    """
    val_dir = yolo_base_path / "images" / "val"
    val_images = sorted(glob.glob(str(val_dir / "*.png")))
    if not val_images:
        raise FileNotFoundError(f"val 이미지가 없습니다: {val_dir}")

    # 샘플링
    if num_samples >= len(val_images):
        sample_paths = val_images
    else:
        sample_paths = random.sample(val_images, num_samples)

    grid = int(np.ceil(np.sqrt(len(sample_paths))))
    fig, axes = plt.subplots(grid, grid, figsize=(5 * grid, 5 * grid))
    axes = np.array(axes).reshape(-1)

    fig.suptitle(f"Validation Predictions (n={len(sample_paths)}, conf≥{conf})", fontsize=14, fontweight="bold")

    for ax, img_path in zip(axes, sample_paths):
        res = model.predict(source=img_path, conf=conf, verbose=False)[0]
        img = res.plot()  # BGR
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        ax.imshow(img)
        ax.set_title(f"{Path(img_path).name}\nDet: {len(res.boxes)}", fontsize=9)
        ax.axis("off")

    for ax in axes[len(sample_paths):]:
        ax.axis("off")

    plt.tight_layout()
    plt.show()


# =========================
# 3) 단일 이미지 상세 분석 (클래스/점수/bbox)
# =========================
def analyze_single_prediction(model, image_path: str, get_name_fn=None, conf: float = 0.25):
    """
    단일 이미지 예측 시각화 + 텍스트 상세 출력
    - get_name_fn: cls_idx -> label 문자열 반환 함수 (없으면 cls_idx만 출력)
    """
    res = model.predict(source=image_path, conf=conf, verbose=False)[0]

    # 시각화 (원본 + 예측)
    original = Image.open(image_path)
    plotted = res.plot()
    plotted = cv2.cvtColor(plotted, cv2.COLOR_BGR2RGB)

    fig, axes = plt.subplots(1, 2, figsize=(14, 6))
    axes[0].imshow(original)
    axes[0].set_title("Original", fontweight="bold")
    axes[0].axis("off")

    axes[1].imshow(plotted)
    axes[1].set_title(f"Prediction (conf≥{conf})", fontweight="bold")
    axes[1].axis("off")

    plt.tight_layout()
    plt.show()

    # 텍스트 요약
    print("\n" + "=" * 90)
    print(f"Image: {Path(image_path).name}")
    print("=" * 90)

    if res.boxes is None or len(res.boxes) == 0:
        print("No detections.")
        return

    # boxes 출력
    for i, b in enumerate(res.boxes, start=1):
        cls_idx = int(b.cls.item())
        name = get_name_fn(cls_idx) if get_name_fn else f"class_{cls_idx}"
        score = float(b.conf.item())
        x1, y1, x2, y2 = [float(v) for v in b.xyxy[0].tolist()]
        print(f"[{i}] {name} | conf={score:.3f} | xyxy=({x1:.1f}, {y1:.1f}, {x2:.1f}, {y2:.1f})")


# =========================
# ✅ 사용 예시 (RUN_DIR / YOLO_BASE_PATH / model 이 이미 있다고 가정)
# =========================
# 1) 학습 아티팩트 보기
show_training_artifacts(RUN_DIR, cols=3)

# 2) val 예측 샘플 그리드
visualize_val_predictions(best_model, YOLO_BASE_PATH, num_samples=9, conf=0.25)

# 3) 단일 이미지 상세 분석 (val에서 랜덤 1장)
get_name = load_names_from_data_yaml(RUN_DIR / "data.yaml")
val_images = glob.glob(str((YOLO_BASE_PATH / "images" / "val") / "*.png"))
random_image = random.choice(val_images)
analyze_single_prediction(best_model, random_image, get_name_fn=get_name, conf=0.25)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# YOLO 모델 1차 테스트 예측 및 결과 도출

# %%
import os
import glob
import pandas as pd
import torch
import gc
from pathlib import Path
from ultralytics import YOLO

# =========================
# 1) 경로 설정
# =========================
DATA_DIR = ROOT_DIR / "data"
TEST_DIR = DATA_DIR / "test_images"

RUN_DIR = ROOT_DIR / "notebooks" / "yolo_runs" / run_name
MODEL_PATH = RUN_DIR / "weights" / "best.pt"

OUT_CSV = ROOT_DIR / f"submission_{run_name}.csv"

assert TEST_DIR.exists(), f"❌ TEST_DIR 없음: {TEST_DIR}"
assert MODEL_PATH.exists(), f"❌ best.pt 없음: {MODEL_PATH}"

print("RUN_DIR:", RUN_DIR)
print("MODEL_PATH:", MODEL_PATH)

# =========================
# 2) 모델 로드 + 메모리 정리
# =========================
torch.cuda.empty_cache()
gc.collect()

model = YOLO(str(MODEL_PATH))

try:
    model.fuse()
except Exception as e:
    print("⚠️ fuse() skip:", e)

# ✅ category_id 매핑은 model.names를 단일 진실로 사용
names = model.names
print("model.names head:",
      list(names.items())[:10] if isinstance(names, dict) else names[:10])

def idx_to_category_id(cls_idx: int) -> int:
    if isinstance(names, dict):
        v = names.get(cls_idx, names.get(str(cls_idx)))
    else:
        v = names[cls_idx]
    return int(v)

# =========================
# 3) 테스트 이미지 목록 (✅ 숫자 정렬)
# =========================
test_image_paths = sorted(
    glob.glob(str(TEST_DIR / "*.png")),
    key=lambda p: int(Path(p).stem)
)
if not test_image_paths:
    raise FileNotFoundError(f"❌ {TEST_DIR} 에 png가 없습니다.")

print(f"총 {len(test_image_paths)}개 테스트 이미지")
print("샘플:", [Path(p).name for p in test_image_paths[:5]])

# =========================
# 4) 예측 → submission rows (✅ PAD 적용)
# =========================
CONF = 0.25
IOU = 0.5
IMGSZ = 640

DEVICE = 0 if torch.cuda.is_available() else "cpu"
USE_HALF = torch.cuda.is_available()

# ✅ 여기서 패딩 픽셀 조절
PAD_X = 11   # 좌/우
PAD_Y = 11   # 상/하

def pad_and_clip_xyxy(x1, y1, x2, y2, W, H, pad_x=0, pad_y=0):
    # pad 적용
    x1 -= pad_x
    y1 -= pad_y
    x2 += pad_x
    y2 += pad_y

    # clip (이미지 밖으로 못 나가게)
    x1 = max(0.0, min(x1, W - 1.0))
    y1 = max(0.0, min(y1, H - 1.0))
    x2 = max(0.0, min(x2, W - 1.0))
    y2 = max(0.0, min(y2, H - 1.0))

    # 혹시 역전되면 최소 1px 보장
    if x2 <= x1:
        x2 = min(W - 1.0, x1 + 1.0)
    if y2 <= y1:
        y2 = min(H - 1.0, y1 + 1.0)

    return x1, y1, x2, y2

rows = []
ann_id = 1

print("🔄 예측 시작...")
for i, img_path in enumerate(test_image_paths):
    if i % 100 == 0:
        print(f"진행률: {i}/{len(test_image_paths)}")

    res = model.predict(
        source=img_path,
        conf=CONF,
        iou=IOU,
        imgsz=IMGSZ,
        device=DEVICE,
        half=USE_HALF,
        verbose=False
    )[0]

    image_id = int(Path(img_path).stem)

    if res.boxes is None or len(res.boxes) == 0:
        continue

    H, W = res.orig_shape

    for box in res.boxes:
        cls_idx = int(box.cls.item())
        category_id = idx_to_category_id(cls_idx)

        x1, y1, x2, y2 = [float(v) for v in box.xyxy[0].tolist()]
        score = float(box.conf.item())

        # ✅ 패딩 + 클리핑 적용
        x1, y1, x2, y2 = pad_and_clip_xyxy(x1, y1, x2, y2, W, H, PAD_X, PAD_Y)

        # xyxy -> xywh
        bbox_x = x1
        bbox_y = y1
        bbox_w = x2 - x1
        bbox_h = y2 - y1

        rows.append({
            "annotation_id": ann_id,
            "image_id": image_id,
            "category_id": category_id,
            "bbox_x": round(bbox_x, 3),
            "bbox_y": round(bbox_y, 3),
            "bbox_w": round(bbox_w, 3),
            "bbox_h": round(bbox_h, 3),
            "score": round(score, 6),
        })
        ann_id += 1

    if i % 100 == 99:
        torch.cuda.empty_cache()
        gc.collect()

torch.cuda.empty_cache()
gc.collect()

# =========================
# 5) CSV 저장
# =========================
sub = pd.DataFrame(rows, columns=[
    "annotation_id", "image_id", "category_id",
    "bbox_x", "bbox_y", "bbox_w", "bbox_h", "score"
])

print(f"\n✅ 총 {len(sub)}개 예측 결과 생성")
print(sub.head())

sub.to_csv(OUT_CSV, index=False)
print(f"💾 저장 완료: {OUT_CSV}")
# Out:
# RUN_DIR: /content/gdrive/MyDrive/AI-06_5team-Object-Detection/notebooks/yolo_runs/20251217_y11m_640_b16_e40_afterpad11_A4_S2?
# MODEL_PATH: /content/gdrive/MyDrive/AI-06_5team-Object-Detection/notebooks/yolo_runs/20251217_y11m_640_b16_e40_afterpad11_A4_S2?/weights/best.pt
# YOLO11m summary (fused): 125 layers, 20,087,086 parameters, 0 gradients, 68.0 GFLOPs
# model.names head: [(0, '1899'), (1, '2482'), (2, '3350'), (3, '3482'), (4, '3543'), (5, '3742'), (6, '3831'), (7, '4377'), (8, '4542'), (9, '5093')]
# 총 843개 테스트 이미지
# 샘플: ['1.png', '3.png', '4.png', '5.png', '8.png']
# 🔄 예측 시작...
# 진행률: 0/843
# 진행률: 100/843
# 진행률: 200/843
# 진행률: 300/843
# 진행률: 400/843
# 진행률: 500/843
# 진행률: 600/843
# 진행률: 700/843
# 진행률: 800/843
#
# ✅ 총 3235개 예측 결과 생성
#    annotation_id  image_id  category_id   bbox_x  bbox_y   bbox_w  bbox_h  \
# 0              1         1        27925  602.000   687.0  232.000   462.0
# 1              2         1        24849  175.125   746.0  168.875   288.0
# 2              3         1         1899  154.500   250.0  206.000   129.0
# 3              4         1        16550  562.000    74.0  378.000   404.0
# 4              5         3        24849  142.000   707.0  171.750   290.0
#
#       score
# 0  0.990234
# 1  0.989746
# 2  0.983887
# 3  0.976074
# 4  0.988281
# 💾 저장 완료: /content/gdrive/MyDrive/AI-06_5team-Object-Detection/submission_20251217_y11m_640_b16_e40_afterpad11_A4_S2?.csv

# %%
import numpy as np

def gini_coefficient(values):
    """
    values: list or np.array of non-negative numbers
    """
    values = np.array(values, dtype=np.float64)
    if np.all(values == 0):
        return 0.0

    values = np.sort(values)
    n = len(values)
    cumulative = np.cumsum(values)
    gini = (n + 1 - 2 * np.sum(cumulative) / cumulative[-1]) / n
    return gini

# %%
from collections import Counter
from pathlib import Path

train_label_dir = YOLO_BASE_PATH / "labels" / "train"

assert train_label_dir.exists(), f"train labels 폴더 없음: {train_label_dir}"

class_counter = Counter()

for label_file in train_label_dir.glob("*.txt"):
    with open(label_file, "r") as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 5:
                continue
            cls_idx = int(parts[0])
            class_counter[cls_idx] += 1

print(f"총 bbox 수: {sum(class_counter.values())}")
print(f"클래스 수: {len(class_counter)}")
# Out:
# 총 bbox 수: 1955
# 클래스 수: 74

# %%
bbox_counts = list(class_counter.values())
gini_s3 = gini_coefficient(bbox_counts)

print(f"📊 S3 이후 Train bbox 기준 Gini: {gini_s3:.4f}")
# Out:
# 📊 S3 이후 Train bbox 기준 Gini: 0.4516

# %%
orig_counter = Counter()

for annots in FIXED_DICT.values():
    for ann in annots:
        orig_counter[ann["label"]] += 1

orig_counts = list(orig_counter.values())
gini_orig = gini_coefficient(orig_counts)

print(f"📊 원본 FIXED_DICT Gini: {gini_orig:.4f}")
print(f"📉 감소폭: {gini_orig - gini_s3:.4f}")
# Out:
# 📊 원본 FIXED_DICT Gini: 0.4489
# 📉 감소폭: -0.0027
